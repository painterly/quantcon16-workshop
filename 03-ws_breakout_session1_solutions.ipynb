# %% [markdown]
# ## Intro to Python for Data Analysis

# %% [markdown]
# ### Break out session 1

# %% [markdown]
# In this breakout session, you will explore some loan data from the Consumer Financial Protection Bureau (www.consumerfinance.gov). This dataset is based on a query that contains
# loan data from 2012 for the state of Vermont.

# %% [markdown]
# ### Examine the data

# %% [markdown]
# Import libraries.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Read in the loans csv file.

# %%
loans=pd.read_csv("loans.csv")

# %% [markdown]
# View the first few rows.

# %%
loans.head(3)
# Out:
#    action_taken action_taken_name  agency_code agency_abbr  \
# 0             1   Loan originated            1         OCC
# 1             1   Loan originated            1         OCC
# 2             1   Loan originated            5        NCUA
#
#                                  agency_name  applicant_ethnicity  \
# 0  Office of the Comptroller of the Currency                    2
# 1  Office of the Comptroller of the Currency                    2
# 2       National Credit Union Administration                    2
#
#   applicant_ethnicity_name  applicant_income_000s  applicant_race_1  \
# 0   Not Hispanic or Latino                    161                 5
# 1   Not Hispanic or Latino                     92                 2
# 2   Not Hispanic or Latino                    106                 5
#
#   applicant_race_name_1          ...            \
# 0                 White          ...
# 1                 Asian          ...
# 2                 White          ...
#
#                                   property_type_name purchaser_type  \
# 0  One-to-four family dwelling (other than manufa...              1
# 1  One-to-four family dwelling (other than manufa...              0
# 2  One-to-four family dwelling (other than manufa...              1
#
#                                  purchaser_type_name  \
# 0                                  Fannie Mae (FNMA)
# 1  Loan was not originated or was not sold in cal...
# 2                                  Fannie Mae (FNMA)
#
#    hud_median_family_income loan_amount_000s  number_of_1_to_4_family_units  \
# 0                     76700              200                           2681
# 1                     76700              279                           2818
# 2                     76700              244                           2447
#
#   number_of_owner_occupied_units  minority_population population  \
# 0                           1186                 7.12       3272
# 1                           2345                 4.58       7144
# 2                           2136                 3.42       6227
#
#    tract_to_msamd_income
# 0              80.459999
# 1             154.830002
# 2             124.199997
#
# [3 rows x 44 columns]

# %% [markdown]
# How many rows and columns are there in the dataset?

# %%
loans.shape
# Out:
# (34573, 44)

# %% [markdown]
# Get the first five rows of the applicant income column by slicing.

# %%
loans['applicant_income_000s'][:5]
# Out:
# 0    161
# 1     92
# 2    106
# 3     49
# 4     74
# Name: applicant_income_000s, dtype: int64

# %% [markdown]
# Get the first five rows of the agency_abbr column using positional indexing.

# %%
loans['agency_abbr'].iloc[:5]
# Out:
# 0     OCC
# 1     OCC
# 2    NCUA
# 3     HUD
# 4     OCC
# Name: agency_abbr, dtype: object

# %%
type(loans.iloc[3,:5])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Sort the data by loan amount in descending order and return the first five rows of the resulting dataframe.

# %%
loans.sort_values(['loan_amount_000s'], ascending=False).head()
# Out:
#        action_taken                      action_taken_name  agency_code  \
# 5654              1                        Loan originated            9
# 21829             2  Application approved but not accepted            9
# 13823             1                        Loan originated            3
# 23790             2  Application approved but not accepted            9
# 16006             1                        Loan originated            9
#
#       agency_abbr                            agency_name  applicant_ethnicity  \
# 5654         CFPB   Consumer Financial Protection Bureau                    3
# 21829        CFPB   Consumer Financial Protection Bureau                    2
# 13823        FDIC  Federal Deposit Insurance Corporation                    2
# 23790        CFPB   Consumer Financial Protection Bureau                    2
# 16006        CFPB   Consumer Financial Protection Bureau                    2
#
#                                 applicant_ethnicity_name  \
# 5654   Information not provided by applicant in mail,...
# 21829                             Not Hispanic or Latino
# 13823                             Not Hispanic or Latino
# 23790                             Not Hispanic or Latino
# 16006                             Not Hispanic or Latino
#
#        applicant_income_000s  applicant_race_1  \
# 5654                    1750                 6
# 21829                   5839                 5
# 13823                   1252                 5
# 23790                    614                 5
# 16006                   1518                 6
#
#                                    applicant_race_name_1  \
# 5654   Information not provided by applicant in mail,...
# 21829                                              White
# 13823                                              White
# 23790                                              White
# 16006  Information not provided by applicant in mail,...
#
#                ...            \
# 5654           ...
# 21829          ...
# 13823          ...
# 23790          ...
# 16006          ...
#
#                                       property_type_name purchaser_type  \
# 5654   One-to-four family dwelling (other than manufa...              0
# 21829  One-to-four family dwelling (other than manufa...              0
# 13823  One-to-four family dwelling (other than manufa...              0
# 23790  One-to-four family dwelling (other than manufa...              0
# 16006  One-to-four family dwelling (other than manufa...              0
#
#                                      purchaser_type_name  \
# 5654   Loan was not originated or was not sold in cal...
# 21829  Loan was not originated or was not sold in cal...
# 13823  Loan was not originated or was not sold in cal...
# 23790  Loan was not originated or was not sold in cal...
# 16006  Loan was not originated or was not sold in cal...
#
#        hud_median_family_income loan_amount_000s  \
# 5654                      76700             2885
# 21829                     63800             2160
# 13823                     63800             2000
# 23790                     63800             2000
# 16006                     63800             2000
#
#        number_of_1_to_4_family_units number_of_owner_occupied_units  \
# 5654                            2818                           2345
# 21829                           1246                            603
# 13823                           2398                           1012
# 23790                           2400                           1559
# 16006                           2400                           1559
#
#        minority_population population  tract_to_msamd_income
# 5654                  4.58       7144             154.830002
# 21829                 2.88       1769              95.379997
# 13823                 2.41       3320             119.320000
# 23790                 4.37       4350              94.580002
# 16006                 4.37       4350              94.580002
#
# [5 rows x 44 columns]

# %% [markdown]
# Get the value counts of action_taken_name column.

# %%
loans['action_taken_name'].value_counts()
# Out:
# Loan originated                                21852
# Application denied by financial institution     4894
# Application withdrawn by applicant              2759
# Loan purchased by the institution               2671
# Application approved but not accepted           1421
# File closed for incompleteness                   976
# Name: action_taken_name, dtype: int64

# %% [markdown]
# Return a boolean value for the preapproval_name column that returns True if preapproval was requested. Display the first four rows.

# %%
loans.ix[0:3,'preapproval_name'] == "Preapproval was requested"
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: preapproval_name, dtype: bool

# %%
loans.loc[0:3,'preapproval_name'] == "Preapproval was requested"
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: preapproval_name, dtype: bool

# %% [markdown]
# Get a subset of the data where applicant income is greater than 0 and less than 1000 (use regular subsetting).

# %%
incomesubset = loans[(loans['applicant_income_000s'] > 0 ) & (loans['applicant_income_000s'] < 1000)]
incomesubset.head()
# Out:
#    action_taken action_taken_name  agency_code agency_abbr  \
# 0             1   Loan originated            1         OCC
# 1             1   Loan originated            1         OCC
# 2             1   Loan originated            5        NCUA
# 3             1   Loan originated            7         HUD
# 4             1   Loan originated            1         OCC
#
#                                    agency_name  applicant_ethnicity  \
# 0    Office of the Comptroller of the Currency                    2
# 1    Office of the Comptroller of the Currency                    2
# 2         National Credit Union Administration                    2
# 3  Department of Housing and Urban Development                    2
# 4    Office of the Comptroller of the Currency                    2
#
#   applicant_ethnicity_name  applicant_income_000s  applicant_race_1  \
# 0   Not Hispanic or Latino                    161                 5
# 1   Not Hispanic or Latino                     92                 2
# 2   Not Hispanic or Latino                    106                 5
# 3   Not Hispanic or Latino                     49                 5
# 4   Not Hispanic or Latino                     74                 5
#
#   applicant_race_name_1          ...            \
# 0                 White          ...
# 1                 Asian          ...
# 2                 White          ...
# 3                 White          ...
# 4                 White          ...
#
#                                   property_type_name purchaser_type  \
# 0  One-to-four family dwelling (other than manufa...              1
# 1  One-to-four family dwelling (other than manufa...              0
# 2  One-to-four family dwelling (other than manufa...              1
# 3  One-to-four family dwelling (other than manufa...              6
# 4  One-to-four family dwelling (other than manufa...              0
#
#                                  purchaser_type_name  \
# 0                                  Fannie Mae (FNMA)
# 1  Loan was not originated or was not sold in cal...
# 2                                  Fannie Mae (FNMA)
# 3  Commercial bank, savings bank or savings assoc...
# 4  Loan was not originated or was not sold in cal...
#
#    hud_median_family_income loan_amount_000s  number_of_1_to_4_family_units  \
# 0                     76700              200                           2681
# 1                     76700              279                           2818
# 2                     76700              244                           2447
# 3                     76700              196                           1810
# 4                     76700               70                           3311
#
#   number_of_owner_occupied_units  minority_population population  \
# 0                           1186                 7.12       3272
# 1                           2345                 4.58       7144
# 2                           2136                 3.42       6227
# 3                           1572                 3.71       5009
# 4                           2874                 5.59       8698
#
#    tract_to_msamd_income
# 0              80.459999
# 1             154.830002
# 2             124.199997
# 3             126.970001
# 4             132.919998
#
# [5 rows x 44 columns]

# %% [markdown]
# Subset the dataframe created in the previous cell to only display applicant income and agency code and display first three rows.

# %%
loans[(loans['applicant_income_000s'] > 0 ) & (loans['applicant_income_000s'] < 1000)][['agency_code', 'applicant_income_000s']][:3]
# Out:
#    agency_code  applicant_income_000s
# 0            1                    161
# 1            1                     92
# 2            5                    106

# %% [markdown]
# Get a subset of the data where applicant income is greater than 0 and less than 1000. Use the query method. Display the applicant income and loan
# amount columns and just the first three rows of data.

# %%
qry1 = loans.query('(applicant_income_000s > 0) & (applicant_income_000s < 1000)')[['applicant_income_000s', 'loan_amount_000s']]
qry1.head(3)
# Out:
#    applicant_income_000s  loan_amount_000s
# 0                    161               200
# 1                     92               279
# 2                    106               244

# %% [markdown]
# ### Groupby and filtering

# %% [markdown]
# Groupby applicant race and loan purpose name and return the mean values.

# %%
loans.groupby(['applicant_race_name_1','loan_purpose_name']).mean()
# Out:
#                                                                       action_taken  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement       1.692308
#                                                    Home purchase          2.578947
#                                                    Refinancing            2.382114
# Asian                                              Home improvement       2.615385
#                                                    Home purchase          2.093458
#                                                    Refinancing            1.886792
# Black or African American                          Home improvement       2.133333
#                                                    Home purchase          2.405405
#                                                    Refinancing            2.240000
# Information not provided by applicant in mail, ... Home improvement       1.993266
#                                                    Home purchase          2.006674
#                                                    Refinancing            2.061628
# Native Hawaiian or Other Pacific Islander          Home improvement       2.750000
#                                                    Home purchase          2.000000
#                                                    Refinancing            2.000000
# Not applicable                                     Home improvement       6.000000
#                                                    Home purchase          6.000000
#                                                    Refinancing            5.941003
# White                                              Home improvement       1.745717
#                                                    Home purchase          2.085156
#                                                    Refinancing            2.016838
#
#                                                                       agency_code  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement      4.538462
#                                                    Home purchase         4.964912
#                                                    Refinancing           4.853659
# Asian                                              Home improvement      5.461538
#                                                    Home purchase         5.663551
#                                                    Refinancing           5.919811
# Black or African American                          Home improvement      6.333333
#                                                    Home purchase         5.324324
#                                                    Refinancing           6.493333
# Information not provided by applicant in mail, ... Home improvement      5.400673
#                                                    Home purchase         6.649611
#                                                    Refinancing           6.404154
# Native Hawaiian or Other Pacific Islander          Home improvement      6.000000
#                                                    Home purchase         5.600000
#                                                    Refinancing           6.578947
# Not applicable                                     Home improvement      9.000000
#                                                    Home purchase         8.184211
#                                                    Refinancing           8.303835
# White                                              Home improvement      5.116822
#                                                    Home purchase         5.544688
#                                                    Refinancing           5.919052
#
#                                                                       applicant_ethnicity  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement              2.000000
#                                                    Home purchase                 2.017544
#                                                    Refinancing                   1.991870
# Asian                                              Home improvement              2.000000
#                                                    Home purchase                 2.009346
#                                                    Refinancing                   2.009434
# Black or African American                          Home improvement              2.000000
#                                                    Home purchase                 1.918919
#                                                    Refinancing                   2.000000
# Information not provided by applicant in mail, ... Home improvement              2.956229
#                                                    Home purchase                 2.921023
#                                                    Refinancing                   2.922029
# Native Hawaiian or Other Pacific Islander          Home improvement              1.750000
#                                                    Home purchase                 2.000000
#                                                    Refinancing                   2.052632
# Not applicable                                     Home improvement              4.000000
#                                                    Home purchase                 4.000000
#                                                    Refinancing                   4.000000
# White                                              Home improvement              2.009346
#                                                    Home purchase                 2.003750
#                                                    Refinancing                   2.005547
#
#                                                                       applicant_income_000s  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement              102.076923
#                                                    Home purchase                  98.842105
#                                                    Refinancing                    89.593496
# Asian                                              Home improvement               88.769231
#                                                    Home purchase                 109.822430
#                                                    Refinancing                   100.179245
# Black or African American                          Home improvement               72.733333
#                                                    Home purchase                  71.405405
#                                                    Refinancing                   104.813333
# Information not provided by applicant in mail, ... Home improvement              106.292929
#                                                    Home purchase                 143.097887
#                                                    Refinancing                   129.036772
# Native Hawaiian or Other Pacific Islander          Home improvement               88.250000
#                                                    Home purchase                 101.700000
#                                                    Refinancing                   101.052632
# Not applicable                                     Home improvement               80.000000
#                                                    Home purchase                 138.934211
#                                                    Refinancing                   119.200590
# White                                              Home improvement               86.008178
#                                                    Home purchase                 105.491875
#                                                    Refinancing                   112.099946
#
#                                                                       applicant_race_1  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement                  1
#                                                    Home purchase                     1
#                                                    Refinancing                       1
# Asian                                              Home improvement                  2
#                                                    Home purchase                     2
#                                                    Refinancing                       2
# Black or African American                          Home improvement                  3
#                                                    Home purchase                     3
#                                                    Refinancing                       3
# Information not provided by applicant in mail, ... Home improvement                  6
#                                                    Home purchase                     6
#                                                    Refinancing                       6
# Native Hawaiian or Other Pacific Islander          Home improvement                  4
#                                                    Home purchase                     4
#                                                    Refinancing                       4
# Not applicable                                     Home improvement                  7
#                                                    Home purchase                     7
#                                                    Refinancing                       7
# White                                              Home improvement                  5
#                                                    Home purchase                     5
#                                                    Refinancing                       5
#
#                                                                       applicant_sex  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement        1.461538
#                                                    Home purchase           1.385965
#                                                    Refinancing             1.308943
# Asian                                              Home improvement        1.538462
#                                                    Home purchase           1.327103
#                                                    Refinancing             1.320755
# Black or African American                          Home improvement        1.266667
#                                                    Home purchase           1.594595
#                                                    Refinancing             1.346667
# Information not provided by applicant in mail, ... Home improvement        2.494949
#                                                    Home purchase           2.483871
#                                                    Refinancing             2.426285
# Native Hawaiian or Other Pacific Islander          Home improvement        1.500000
#                                                    Home purchase           1.300000
#                                                    Refinancing             1.105263
# Not applicable                                     Home improvement        4.000000
#                                                    Home purchase           4.000000
#                                                    Refinancing             4.000000
# White                                              Home improvement        1.356308
#                                                    Home purchase           1.333438
#                                                    Refinancing             1.305778
#
#                                                                       census_tract_number  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement           6661.923077
#                                                    Home purchase              3227.267368
#                                                    Refinancing                3465.027398
# Asian                                              Home improvement           3715.233077
#                                                    Home purchase              3158.742710
#                                                    Refinancing                2479.789198
# Black or African American                          Home improvement           4513.604000
#                                                    Home purchase              5467.111622
#                                                    Refinancing                4760.790267
# Information not provided by applicant in mail, ... Home improvement           6323.345926
#                                                    Home purchase              5290.150067
#                                                    Refinancing                5229.722918
# Native Hawaiian or Other Pacific Islander          Home improvement           2494.760000
#                                                    Home purchase              2931.300000
#                                                    Refinancing                3565.161579
# Not applicable                                     Home improvement           9604.000000
#                                                    Home purchase              6578.648289
#                                                    Refinancing                5036.917640
# White                                              Home improvement           6024.937099
#                                                    Home purchase              5526.173983
#                                                    Refinancing                5384.464213
#
#                                                                       co_applicant_ethnicity  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement                 3.384615
#                                                    Home purchase                    3.456140
#                                                    Refinancing                      3.333333
# Asian                                              Home improvement                 3.153846
#                                                    Home purchase                    3.196262
#                                                    Refinancing                      3.367925
# Black or African American                          Home improvement                 3.000000
#                                                    Home purchase                    3.864865
#                                                    Refinancing                      3.733333
# Information not provided by applicant in mail, ... Home improvement                 3.653199
#                                                    Home purchase                    3.731924
#                                                    Refinancing                      3.647600
# Native Hawaiian or Other Pacific Islander          Home improvement                 4.250000
#                                                    Home purchase                    3.900000
#                                                    Refinancing                      3.105263
# Not applicable                                     Home improvement                 4.000000
#                                                    Home purchase                    4.131579
#                                                    Refinancing                      4.005900
# White                                              Home improvement                 3.136293
#                                                    Home purchase                    3.414687
#                                                    Refinancing                      3.101811
#
#                                                                       co_applicant_race_1  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement              6.461538
#                                                    Home purchase                 5.701754
#                                                    Refinancing                   5.154472
# Asian                                              Home improvement              5.461538
#                                                    Home purchase                 5.196262
#                                                    Refinancing                   5.353774
# Black or African American                          Home improvement              5.000000
#                                                    Home purchase                 6.648649
#                                                    Refinancing                   6.453333
# Information not provided by applicant in mail, ... Home improvement              6.693603
#                                                    Home purchase                 6.753059
#                                                    Refinancing                   6.674157
# Native Hawaiian or Other Pacific Islander          Home improvement              7.000000
#                                                    Home purchase                 6.800000
#                                                    Refinancing                   6.105263
# Not applicable                                     Home improvement              7.000000
#                                                    Home purchase                 7.105263
#                                                    Refinancing                   7.000000
# White                                              Home improvement              6.104361
#                                                    Home purchase                 6.389531
#                                                    Refinancing                   6.082077
#
#                                                                       co_applicant_sex  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement           3.307692
#                                                    Home purchase              3.280702
#                                                    Refinancing                3.227642
# Asian                                              Home improvement           2.923077
#                                                    Home purchase              2.962617
#                                                    Refinancing                3.198113
# Black or African American                          Home improvement           2.933333
#                                                    Home purchase              3.729730
#                                                    Refinancing                3.666667
# Information not provided by applicant in mail, ... Home improvement           3.407407
#                                                    Home purchase              3.543938
#                                                    Refinancing                3.413347
# Native Hawaiian or Other Pacific Islander          Home improvement           4.000000
#                                                    Home purchase              3.700000
#                                                    Refinancing                3.052632
# Not applicable                                     Home improvement           4.000000
#                                                    Home purchase              4.131579
#                                                    Refinancing                3.994100
# White                                              Home improvement           2.961059
#                                                    Home purchase              3.276719
#                                                    Refinancing                2.957243
#
#                                                                               ...            \
# applicant_race_name_1                              loan_purpose_name          ...
# American Indian or Alaska Native                   Home improvement           ...
#                                                    Home purchase              ...
#                                                    Refinancing                ...
# Asian                                              Home improvement           ...
#                                                    Home purchase              ...
#                                                    Refinancing                ...
# Black or African American                          Home improvement           ...
#                                                    Home purchase              ...
#                                                    Refinancing                ...
# Information not provided by applicant in mail, ... Home improvement           ...
#                                                    Home purchase              ...
#                                                    Refinancing                ...
# Native Hawaiian or Other Pacific Islander          Home improvement           ...
#                                                    Home purchase              ...
#                                                    Refinancing                ...
# Not applicable                                     Home improvement           ...
#                                                    Home purchase              ...
#                                                    Refinancing                ...
# White                                              Home improvement           ...
#                                                    Home purchase              ...
#                                                    Refinancing                ...
#
#                                                                       preapproval  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement      3.000000
#                                                    Home purchase         2.736842
#                                                    Refinancing           3.000000
# Asian                                              Home improvement      3.000000
#                                                    Home purchase         2.654206
#                                                    Refinancing           3.000000
# Black or African American                          Home improvement      3.000000
#                                                    Home purchase         2.513514
#                                                    Refinancing           3.000000
# Information not provided by applicant in mail, ... Home improvement      3.000000
#                                                    Home purchase         2.440489
#                                                    Refinancing           3.000000
# Native Hawaiian or Other Pacific Islander          Home improvement      3.000000
#                                                    Home purchase         2.700000
#                                                    Refinancing           3.000000
# Not applicable                                     Home improvement      3.000000
#                                                    Home purchase         3.000000
#                                                    Refinancing           3.000000
# White                                              Home improvement      3.000000
#                                                    Home purchase         2.620625
#                                                    Refinancing           3.000000
#
#                                                                       property_type  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement        1.076923
#                                                    Home purchase           1.070175
#                                                    Refinancing             1.040650
# Asian                                              Home improvement        1.076923
#                                                    Home purchase           1.000000
#                                                    Refinancing             1.000000
# Black or African American                          Home improvement        1.066667
#                                                    Home purchase           1.000000
#                                                    Refinancing             1.000000
# Information not provided by applicant in mail, ... Home improvement        1.023569
#                                                    Home purchase           1.033370
#                                                    Refinancing             1.009874
# Native Hawaiian or Other Pacific Islander          Home improvement        1.000000
#                                                    Home purchase           1.000000
#                                                    Refinancing             1.000000
# Not applicable                                     Home improvement        1.000000
#                                                    Home purchase           1.000000
#                                                    Refinancing             1.000000
# White                                              Home improvement        1.040109
#                                                    Home purchase           1.037969
#                                                    Refinancing             1.019390
#
#                                                                       purchaser_type  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement         0.461538
#                                                    Home purchase            2.421053
#                                                    Refinancing              1.577236
# Asian                                              Home improvement         1.384615
#                                                    Home purchase            2.401869
#                                                    Refinancing              1.599057
# Black or African American                          Home improvement         0.933333
#                                                    Home purchase            2.027027
#                                                    Refinancing              1.306667
# Information not provided by applicant in mail, ... Home improvement         0.508418
#                                                    Home purchase            1.961068
#                                                    Refinancing              1.324481
# Native Hawaiian or Other Pacific Islander          Home improvement         0.000000
#                                                    Home purchase            2.900000
#                                                    Refinancing              2.736842
# Not applicable                                     Home improvement         8.000000
#                                                    Home purchase            2.460526
#                                                    Refinancing              2.162242
# White                                              Home improvement         0.762461
#                                                    Home purchase            2.402031
#                                                    Refinancing              1.523293
#
#                                                                       hud_median_family_income  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement               67769.230769
#                                                    Home purchase                  72400.000000
#                                                    Refinancing                    72085.365854
# Asian                                              Home improvement               71738.461538
#                                                    Home purchase                  72480.373832
#                                                    Refinancing                    73414.150943
# Black or African American                          Home improvement               70680.000000
#                                                    Home purchase                  69378.378378
#                                                    Refinancing                    70336.000000
# Information not provided by applicant in mail, ... Home improvement               68230.303030
#                                                    Home purchase                  69625.806452
#                                                    Refinancing                    69707.558733
# Native Hawaiian or Other Pacific Islander          Home improvement               73475.000000
#                                                    Home purchase                  72830.000000
#                                                    Refinancing                    71947.368421
# Not applicable                                     Home improvement               63800.000000
#                                                    Home purchase                  67873.684211
#                                                    Refinancing                    69964.601770
# White                                              Home improvement               68622.429907
#                                                    Home purchase                  69306.687500
#                                                    Refinancing                    69496.745373
#
#                                                                       loan_amount_000s  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement          64.615385
#                                                    Home purchase            176.912281
#                                                    Refinancing              179.951220
# Asian                                              Home improvement         106.000000
#                                                    Home purchase            191.598131
#                                                    Refinancing              190.235849
# Black or African American                          Home improvement          77.800000
#                                                    Home purchase            183.216216
#                                                    Refinancing              192.746667
# Information not provided by applicant in mail, ... Home improvement          97.000000
#                                                    Home purchase            213.720801
#                                                    Refinancing              190.172966
# Native Hawaiian or Other Pacific Islander          Home improvement          82.000000
#                                                    Home purchase            188.500000
#                                                    Refinancing              188.894737
# Not applicable                                     Home improvement         177.000000
#                                                    Home purchase            205.276316
#                                                    Refinancing              193.781711
# White                                              Home improvement         106.154206
#                                                    Home purchase            186.630625
#                                                    Refinancing              182.811791
#
#                                                                       number_of_1_to_4_family_units  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement                     1641.000000
#                                                    Home purchase                        1669.473684
#                                                    Refinancing                          1849.016260
# Asian                                              Home improvement                     1728.076923
#                                                    Home purchase                        1629.392523
#                                                    Refinancing                          1754.419811
# Black or African American                          Home improvement                     1935.800000
#                                                    Home purchase                        1576.270270
#                                                    Refinancing                          1789.013333
# Information not provided by applicant in mail, ... Home improvement                     1730.208754
#                                                    Home purchase                        1755.659622
#                                                    Refinancing                          1820.762683
# Native Hawaiian or Other Pacific Islander          Home improvement                     2067.500000
#                                                    Home purchase                        1580.300000
#                                                    Refinancing                          1618.578947
# Not applicable                                     Home improvement                     2285.000000
#                                                    Home purchase                        1804.868421
#                                                    Refinancing                          1847.976401
# White                                              Home improvement                     1799.087617
#                                                    Home purchase                        1827.103281
#                                                    Refinancing                          1835.042315
#
#                                                                       number_of_owner_occupied_units  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement                      1195.692308
#                                                    Home purchase                         1188.631579
#                                                    Refinancing                           1309.455285
# Asian                                              Home improvement                      1268.538462
#                                                    Home purchase                         1174.971963
#                                                    Refinancing                           1281.566038
# Black or African American                          Home improvement                      1430.266667
#                                                    Home purchase                         1086.054054
#                                                    Refinancing                           1211.760000
# Information not provided by applicant in mail, ... Home improvement                      1193.952862
#                                                    Home purchase                         1156.041157
#                                                    Refinancing                           1238.682329
# Native Hawaiian or Other Pacific Islander          Home improvement                      1354.250000
#                                                    Home purchase                          853.700000
#                                                    Refinancing                           1124.473684
# Not applicable                                     Home improvement                      1721.000000
#                                                    Home purchase                         1086.894737
#                                                    Refinancing                           1223.746313
# White                                              Home improvement                      1239.919393
#                                                    Home purchase                         1242.711094
#                                                    Refinancing                           1260.212901
#
#                                                                       minority_population  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement              4.487692
#                                                    Home purchase                 7.057544
#                                                    Refinancing                   7.006748
# Asian                                              Home improvement              7.818462
#                                                    Home purchase                 8.887570
#                                                    Refinancing                   8.399057
# Black or African American                          Home improvement              6.383333
#                                                    Home purchase                 8.095676
#                                                    Refinancing                   7.225600
# Information not provided by applicant in mail, ... Home improvement              4.868754
#                                                    Home purchase                 5.911279
#                                                    Refinancing                   5.542196
# Native Hawaiian or Other Pacific Islander          Home improvement              6.192500
#                                                    Home purchase                10.998000
#                                                    Refinancing                   7.741053
# Not applicable                                     Home improvement              3.650000
#                                                    Home purchase                 5.513158
#                                                    Refinancing                   5.534897
# White                                              Home improvement              5.064965
#                                                    Home purchase                 5.636495
#                                                    Refinancing                   5.438464
#
#                                                                        population  \
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement   3862.846154
#                                                    Home purchase      4095.192982
#                                                    Refinancing        4550.991870
# Asian                                              Home improvement   4061.076923
#                                                    Home purchase      4183.915888
#                                                    Refinancing        4402.056604
# Black or African American                          Home improvement   4678.733333
#                                                    Home purchase      4112.756757
#                                                    Refinancing        4385.773333
# Information not provided by applicant in mail, ... Home improvement   3877.255892
#                                                    Home purchase      3925.969967
#                                                    Refinancing        4098.827375
# Native Hawaiian or Other Pacific Islander          Home improvement   4558.000000
#                                                    Home purchase      3290.100000
#                                                    Refinancing        4173.947368
# Not applicable                                     Home improvement   5094.000000
#                                                    Home purchase      3552.131579
#                                                    Refinancing        4092.135693
# White                                              Home improvement   4083.890966
#                                                    Home purchase      4173.643906
#                                                    Refinancing        4180.187423
#
#                                                                       tract_to_msamd_income
# applicant_race_name_1                              loan_purpose_name
# American Indian or Alaska Native                   Home improvement              101.520000
#                                                    Home purchase                 104.059122
#                                                    Refinancing                   102.170162
# Asian                                              Home improvement              108.128461
#                                                    Home purchase                 107.478037
#                                                    Refinancing                   107.227122
# Black or African American                          Home improvement               94.532000
#                                                    Home purchase                  97.002702
#                                                    Refinancing                   101.771866
# Information not provided by applicant in mail, ... Home improvement              104.221818
#                                                    Home purchase                 108.059610
#                                                    Refinancing                   108.765121
# Native Hawaiian or Other Pacific Islander          Home improvement               94.682499
#                                                    Home purchase                  87.122999
#                                                    Refinancing                   102.384737
# Not applicable                                     Home improvement              120.339996
#                                                    Home purchase                 110.636710
#                                                    Refinancing                   110.617080
# White                                              Home improvement              103.346051
#                                                    Home purchase                 103.814998
#                                                    Refinancing                   106.312604
#
# [21 rows x 26 columns]

# %% [markdown]
# Filter the dataset to return only rows containing NCUA in the agency_abbr column.

# %%
loans[loans['agency_abbr'].isin(['NCUA'])].head()
# Out:
#     action_taken action_taken_name  agency_code agency_abbr  \
# 2              1   Loan originated            5        NCUA
# 7              1   Loan originated            5        NCUA
# 11             1   Loan originated            5        NCUA
# 15             1   Loan originated            5        NCUA
# 27             1   Loan originated            5        NCUA
#
#                              agency_name  applicant_ethnicity  \
# 2   National Credit Union Administration                    2
# 7   National Credit Union Administration                    2
# 11  National Credit Union Administration                    2
# 15  National Credit Union Administration                    2
# 27  National Credit Union Administration                    2
#
#    applicant_ethnicity_name  applicant_income_000s  applicant_race_1  \
# 2    Not Hispanic or Latino                    106                 5
# 7    Not Hispanic or Latino                     93                 5
# 11   Not Hispanic or Latino                     58                 5
# 15   Not Hispanic or Latino                     72                 5
# 27   Not Hispanic or Latino                     91                 5
#
#    applicant_race_name_1          ...            \
# 2                  White          ...
# 7                  White          ...
# 11                 White          ...
# 15                 White          ...
# 27                 White          ...
#
#                                    property_type_name purchaser_type  \
# 2   One-to-four family dwelling (other than manufa...              1
# 7   One-to-four family dwelling (other than manufa...              1
# 11  One-to-four family dwelling (other than manufa...              0
# 15  One-to-four family dwelling (other than manufa...              6
# 27  One-to-four family dwelling (other than manufa...              0
#
#                                   purchaser_type_name  \
# 2                                   Fannie Mae (FNMA)
# 7                                   Fannie Mae (FNMA)
# 11  Loan was not originated or was not sold in cal...
# 15  Commercial bank, savings bank or savings assoc...
# 27  Loan was not originated or was not sold in cal...
#
#     hud_median_family_income loan_amount_000s  number_of_1_to_4_family_units  \
# 2                      76700              244                           2447
# 7                      63800              150                           1562
# 11                     76700               70                           1994
# 15                     76700              154                           2236
# 27                     76700               70                           1359
#
#    number_of_owner_occupied_units  minority_population population  \
# 2                            2136                 3.42       6227
# 7                            1257                 4.01       3870
# 11                           1725                 4.44       5070
# 15                           1672                 8.53       5625
# 27                            589                 7.56       3451
#
#     tract_to_msamd_income
# 2              124.199997
# 7              108.949997
# 11             121.349998
# 15              97.500000
# 27              62.650002
#
# [5 rows x 44 columns]

# %% [markdown]
# Group by purchaser type name and get the median values using the aggregate method.

# %%
loans.groupby('purchaser_type_name').aggregate(np.median)
# Out:
#                                                     action_taken  agency_code  \
# purchaser_type_name
# Affiliate institution                                          1            9
# Commercial bank, savings bank or savings associ...             1            7
# Fannie Mae (FNMA)                                              1            7
# Freddie Mac (FHLMC)                                            1            5
# Ginnie Mae (GNMA)                                              1            9
# Life insurance company, credit union, mortgage ...             1            7
# Loan was not originated or was not sold in cale...             2            5
# Other type of purchaser                                        1            3
# Private securitization                                         1            9
#
#                                                     applicant_ethnicity  \
# purchaser_type_name
# Affiliate institution                                                 2
# Commercial bank, savings bank or savings associ...                    2
# Fannie Mae (FNMA)                                                     2
# Freddie Mac (FHLMC)                                                   2
# Ginnie Mae (GNMA)                                                     2
# Life insurance company, credit union, mortgage ...                    2
# Loan was not originated or was not sold in cale...                    2
# Other type of purchaser                                               2
# Private securitization                                                2
#
#                                                     applicant_income_000s  \
# purchaser_type_name
# Affiliate institution                                                  80
# Commercial bank, savings bank or savings associ...                     83
# Fannie Mae (FNMA)                                                      91
# Freddie Mac (FHLMC)                                                    87
# Ginnie Mae (GNMA)                                                      64
# Life insurance company, credit union, mortgage ...                     78
# Loan was not originated or was not sold in cale...                     76
# Other type of purchaser                                                66
# Private securitization                                                 97
#
#                                                     applicant_race_1  \
# purchaser_type_name
# Affiliate institution                                              5
# Commercial bank, savings bank or savings associ...                 5
# Fannie Mae (FNMA)                                                  5
# Freddie Mac (FHLMC)                                                5
# Ginnie Mae (GNMA)                                                  5
# Life insurance company, credit union, mortgage ...                 5
# Loan was not originated or was not sold in cale...                 5
# Other type of purchaser                                            5
# Private securitization                                             5
#
#                                                     applicant_sex  \
# purchaser_type_name
# Affiliate institution                                           1
# Commercial bank, savings bank or savings associ...              1
# Fannie Mae (FNMA)                                               1
# Freddie Mac (FHLMC)                                             1
# Ginnie Mae (GNMA)                                               1
# Life insurance company, credit union, mortgage ...              1
# Loan was not originated or was not sold in cale...              1
# Other type of purchaser                                         1
# Private securitization                                          1
#
#                                                     census_tract_number  \
# purchaser_type_name
# Affiliate institution                                              9543
# Commercial bank, savings bank or savings associ...                  101
# Fannie Mae (FNMA)                                                  9545
# Freddie Mac (FHLMC)                                                 102
# Ginnie Mae (GNMA)                                                  9541
# Life insurance company, credit union, mortgage ...                  108
# Loan was not originated or was not sold in cale...                 9541
# Other type of purchaser                                            9516
# Private securitization                                             9551
#
#                                                     co_applicant_ethnicity  \
# purchaser_type_name
# Affiliate institution                                                    3
# Commercial bank, savings bank or savings associ...                       2
# Fannie Mae (FNMA)                                                        2
# Freddie Mac (FHLMC)                                                      2
# Ginnie Mae (GNMA)                                                        3
# Life insurance company, credit union, mortgage ...                       2
# Loan was not originated or was not sold in cale...                       2
# Other type of purchaser                                                  3
# Private securitization                                                   2
#
#                                                     co_applicant_race_1  \
# purchaser_type_name
# Affiliate institution                                                 6
# Commercial bank, savings bank or savings associ...                    5
# Fannie Mae (FNMA)                                                     5
# Freddie Mac (FHLMC)                                                   5
# Ginnie Mae (GNMA)                                                     6
# Life insurance company, credit union, mortgage ...                    5
# Loan was not originated or was not sold in cale...                    5
# Other type of purchaser                                               6
# Private securitization                                                5
#
#                                                     co_applicant_sex  \
# purchaser_type_name
# Affiliate institution                                            2.5
# Commercial bank, savings bank or savings associ...               2.0
# Fannie Mae (FNMA)                                                2.0
# Freddie Mac (FHLMC)                                              2.0
# Ginnie Mae (GNMA)                                                3.0
# Life insurance company, credit union, mortgage ...               2.0
# Loan was not originated or was not sold in cale...               2.0
# Other type of purchaser                                          2.0
# Private securitization                                           2.0
#
#                                                             ...            \
# purchaser_type_name                                         ...
# Affiliate institution                                       ...
# Commercial bank, savings bank or savings associ...          ...
# Fannie Mae (FNMA)                                           ...
# Freddie Mac (FHLMC)                                         ...
# Ginnie Mae (GNMA)                                           ...
# Life insurance company, credit union, mortgage ...          ...
# Loan was not originated or was not sold in cale...          ...
# Other type of purchaser                                     ...
# Private securitization                                      ...
#
#                                                     preapproval  \
# purchaser_type_name
# Affiliate institution                                         3
# Commercial bank, savings bank or savings associ...            3
# Fannie Mae (FNMA)                                             3
# Freddie Mac (FHLMC)                                           3
# Ginnie Mae (GNMA)                                             3
# Life insurance company, credit union, mortgage ...            3
# Loan was not originated or was not sold in cale...            3
# Other type of purchaser                                       3
# Private securitization                                        3
#
#                                                     property_type  \
# purchaser_type_name
# Affiliate institution                                           1
# Commercial bank, savings bank or savings associ...              1
# Fannie Mae (FNMA)                                               1
# Freddie Mac (FHLMC)                                             1
# Ginnie Mae (GNMA)                                               1
# Life insurance company, credit union, mortgage ...              1
# Loan was not originated or was not sold in cale...              1
# Other type of purchaser                                         1
# Private securitization                                          1
#
#                                                     purchaser_type  \
# purchaser_type_name
# Affiliate institution                                            8
# Commercial bank, savings bank or savings associ...               6
# Fannie Mae (FNMA)                                                1
# Freddie Mac (FHLMC)                                              3
# Ginnie Mae (GNMA)                                                2
# Life insurance company, credit union, mortgage ...               7
# Loan was not originated or was not sold in cale...               0
# Other type of purchaser                                          9
# Private securitization                                           5
#
#                                                     hud_median_family_income  \
# purchaser_type_name
# Affiliate institution                                                  63800
# Commercial bank, savings bank or savings associ...                     76700
# Fannie Mae (FNMA)                                                      63800
# Freddie Mac (FHLMC)                                                    76700
# Ginnie Mae (GNMA)                                                      63800
# Life insurance company, credit union, mortgage ...                     76700
# Loan was not originated or was not sold in cale...                     63800
# Other type of purchaser                                                63800
# Private securitization                                                 63800
#
#                                                     loan_amount_000s  \
# purchaser_type_name
# Affiliate institution                                            155
# Commercial bank, savings bank or savings associ...               192
# Fannie Mae (FNMA)                                                178
# Freddie Mac (FHLMC)                                              179
# Ginnie Mae (GNMA)                                                182
# Life insurance company, credit union, mortgage ...               190
# Loan was not originated or was not sold in cale...               142
# Other type of purchaser                                          168
# Private securitization                                           185
#
#                                                     number_of_1_to_4_family_units  \
# purchaser_type_name
# Affiliate institution                                                      1629.0
# Commercial bank, savings bank or savings associ...                         1783.0
# Fannie Mae (FNMA)                                                          1732.0
# Freddie Mac (FHLMC)                                                        1719.0
# Ginnie Mae (GNMA)                                                          1759.0
# Life insurance company, credit union, mortgage ...                         1772.5
# Loan was not originated or was not sold in cale...                         1718.0
# Other type of purchaser                                                    1611.0
# Private securitization                                                     1714.0
#
#                                                     number_of_owner_occupied_units  \
# purchaser_type_name
# Affiliate institution                                                       1053.0
# Commercial bank, savings bank or savings associ...                          1325.0
# Fannie Mae (FNMA)                                                           1182.0
# Freddie Mac (FHLMC)                                                         1281.0
# Ginnie Mae (GNMA)                                                           1259.0
# Life insurance company, credit union, mortgage ...                          1407.5
# Loan was not originated or was not sold in cale...                          1182.0
# Other type of purchaser                                                     1098.0
# Private securitization                                                      1186.0
#
#                                                     minority_population  \
# purchaser_type_name
# Affiliate institution                                              4.08
# Commercial bank, savings bank or savings associ...                 4.58
# Fannie Mae (FNMA)                                                  4.38
# Freddie Mac (FHLMC)                                                4.45
# Ginnie Mae (GNMA)                                                  4.36
# Life insurance company, credit union, mortgage ...                 4.45
# Loan was not originated or was not sold in cale...                 4.23
# Other type of purchaser                                            4.38
# Private securitization                                             4.11
#
#                                                     population  \
# purchaser_type_name
# Affiliate institution                                     3414
# Commercial bank, savings bank or savings associ...        4371
# Fannie Mae (FNMA)                                         3957
# Freddie Mac (FHLMC)                                       4211
# Ginnie Mae (GNMA)                                         4187
# Life insurance company, credit union, mortgage ...        4381
# Loan was not originated or was not sold in cale...        3870
# Other type of purchaser                                   3894
# Private securitization                                    4054
#
#                                                     tract_to_msamd_income
# purchaser_type_name
# Affiliate institution                                          100.519997
# Commercial bank, savings bank or savings associ...             104.209999
# Fannie Mae (FNMA)                                              105.000000
# Freddie Mac (FHLMC)                                            104.230003
# Ginnie Mae (GNMA)                                              101.639999
# Life insurance company, credit union, mortgage ...             104.209999
# Loan was not originated or was not sold in cale...             103.959999
# Other type of purchaser                                        102.349998
# Private securitization                                         105.230003
#
# [9 rows x 26 columns]

# %% [markdown]
# ### Visualizations

# %% [markdown]
# Create a simple bar plot with loan purpose on the x-axis and loan amount on the y-axis with Seaborn.

# %%
sns.barplot("loan_purpose_name", "loan_amount_000s", data=loans)

# %% [markdown]
# Create a simple boxplot with loan_amount on the x-axis and agency_name on the y-axis with Seaborn. Make the loan amount log scale in the plot.

# %%
ax = sns.boxplot(x="loan_amount_000s", y="agency_name", data=loans,
                 whis=np.inf, color="c")
ax.set_xscale("log")
sns.despine(trim=True)

# %% [markdown]
# Create a violin plot with loan amount on the x-axis and loan purpose name on the y-axis with Seaborn.

# %%
sns.violinplot(loans["loan_amount_000s"], loans["loan_purpose_name"])
sns.despine(left=True);

# %% [markdown]
# Display all column names.

# %%
loans.columns
# Out:
# Index(['action_taken', 'action_taken_name', 'agency_code', 'agency_abbr',
#        'agency_name', 'applicant_ethnicity', 'applicant_ethnicity_name',
#        'applicant_income_000s', 'applicant_race_1', 'applicant_race_name_1',
#        'applicant_sex', 'applicant_sex_name', 'census_tract_number',
#        'co_applicant_ethnicity', 'co_applicant_ethnicity_name',
#        'co_applicant_race_1', 'co_applicant_race_name_1', 'co_applicant_sex',
#        'co_applicant_sex_name', 'county_code', 'county_name', 'hoepa_status',
#        'hoepa_status_name', 'lien_status', 'lien_status_name', 'loan_purpose',
#        'loan_purpose_name', 'loan_type', 'loan_type_name', 'owner_occupancy',
#        'owner_occupancy_name', 'preapproval', 'preapproval_name',
#        'property_type', 'property_type_name', 'purchaser_type',
#        'purchaser_type_name', 'hud_median_family_income', 'loan_amount_000s',
#        'number_of_1_to_4_family_units', 'number_of_owner_occupied_units',
#        'minority_population', 'population', 'tract_to_msamd_income'],
#       dtype='object')

# %% [markdown]
# Show unique values for action taken name column.

# %%
loans.action_taken_name.unique()
# Out:
# array(['Loan originated', 'Application approved but not accepted',
#        'Application denied by financial institution',
#        'Application withdrawn by applicant',
#        'File closed for incompleteness',
#        'Loan purchased by the institution'], dtype=object)
